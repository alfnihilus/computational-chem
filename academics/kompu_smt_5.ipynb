# %% [markdown]
# <a href="https://colab.research.google.com/github/alfnihilus/computational-chem/blob/main/academics/kompu_smt_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Instal tidak spesifik

# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:06
# 🔁 Restarting kernel...

# %%
# @title Instal spesifik
# !pip install -q condacolab
import condacolab
# Mengunduh installer Miniforge Linux 64-bit terbaru
condacolab.install_from_url("https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-Linux-x86_64.sh")
# Out:
# ✨🍰✨ Everything looks OK!

# %%
import subprocess

# Membersihkan pembatasan meta-data bawaan Colab
subprocess.run("rm -rf /usr/local/conda-meta/pinned", shell=True)

# Menginstal AmberTools menggunakan mamba (proses ini memakan waktu sekitar 2-4 menit)
print("Sedang menginstal AmberTools, mohon tunggu...")
subprocess.run("mamba install -c conda-forge ambertools -y", shell=True)
print("Instalasi AmberTools Selesai!")
# Out:
# Sedang menginstal AmberTools, mohon tunggu...
# Instalasi AmberTools Selesai!

# %%
# Jalankan ini jika kamu butuh engine simulasi berbasis GPU di Colab
# !mamba install -c conda-forge openmm -y
# !pip install -q py3Dmol MDAnalysis
# Out:
# Looking for: ['openmm']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.11.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - openmm
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package              Version  Build            Channel          Size
# ────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────
#
#   + rocm-core            7.0.2  h54a6638_0       conda-forge      20kB
#   + opencl-headers  2025.06.13  hecca717_0       conda-forge      56kB
#   + ocl-icd              2.3.3  hb9d3cd8_0       conda-forge     107kB
#   + ocl-icd-system       1.0.0  1                conda-forge       4kB
#   + cuda-version          13.3  hcbadf70_3       conda-forge      22kB
# ...

# %%
# %%bash
# # Memeriksa apakah perintah utama AmberTools sudah terbaca di sistem
# echo "=== Verifikasi Leap ==="
# tleap -h | head -n 1
#
# echo -e "\n=== Verifikasi Antechamber ==="
# antechamber -h | head -n 4
#
# echo -e "\n=== Verifikasi Cpptraj ==="
# cpptraj --version | head -n 1
# Out:
# === Verifikasi Leap ===
# -I: Adding /usr/local/dat/leap/prep to search path.
#
# === Verifikasi Antechamber ===
# Usage: antechamber -i     input file name
#                    -fi    input file format
#                    -o     output file name
#                    -fo    output file format
#
# === Verifikasi Cpptraj ===
# CPPTRAJ: Version V6.24.0 (AmberTools)

# %%
# @title Bukti Ambertools & Amber telah terinstal

# %%bash
echo "=== 1. CEK LOKASI INSTALASI ==="
which tleap
which antechamber

echo -e "\n=== 2. CEK VERSI CPPTRAJ ==="
cpptraj --version | head -n 2

echo -e "\n=== 3. TES EKSEKUSI LEAP ==="
tleap -h | head -n 1
# Out:
# === 1. CEK LOKASI INSTALASI ===
# /usr/local/bin/tleap
# /usr/local/bin/antechamber
#
# === 2. CEK VERSI CPPTRAJ ===
# CPPTRAJ: Version V6.24.0 (AmberTools)
#
# === 3. TES EKSEKUSI LEAP ===
# -I: Adding /usr/local/dat/leap/prep to search path.
